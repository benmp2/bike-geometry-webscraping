# %% [markdown]
# ## Imports:

# %%
# %load_ext autoreload
# %autoreload 2

import logging
from skimage import io
import matplotlib.pyplot as plt
from IPython.display import SVG, display

from scraper.canyon_scraper import canyon_geometry_scraper
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Canyon bikes' geometry web scraping:

# %% [markdown]
# ### Generate dataframe:

# %%
# site_url1 = 'https://www.canyon.com/en-hu/road-bikes/race-bikes/aeroad/aeroad-cfr-disc-eps/2493.html'
# site_url1 = 'https://www.canyon.com/en-hu/mountain-bikes/trail-bikes/spectral/spectral-29-ltd/2682.html'
site_url1 = "https://www.canyon.com/en-gb/hybrid-bikes/city-bikes/roadlite/roadlite-5/2780.html"

scraper = canyon_geometry_scraper(site_url = site_url1)
df = scraper.generate_df()
df
# Out:
#                                                 XS          S          M  \
# Body Height in cm                            < 166  166 - 174  174 - 182
# Seat Height in mm (a)                    630 - 730  670 - 770  710 - 810
# Seat Tube Length in mm (b)                     442        482        522
# Top Tube Length in mm (c)                      558        575        587
# Head Tube Length in mm (d)                     100        105        130
# Head Tube Angle (e)                         72,15°     72,15°     72,15°
# Seat Tube Angle (f)                          73,5°      73,5°      73,5°
# Chainstay Length in mm (g)                     415        415        415
# Wheel Base in mm (h)                         1.011      1.022      1.035
# Stack in mm (i)                                522        540        563
# Reach in mm (j)                                403        415        420
# Stand-over Height in mm (k)                    720        750        800
# ...

# %% [markdown]
# ### Frame geometry image:

# %%
display(SVG(url=scraper.get_frame_geom_img_url()))

# %% [markdown]
# ## Trek bikes' geometry web scraping:
