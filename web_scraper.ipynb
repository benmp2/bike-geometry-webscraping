# %% [markdown]
# ## Imports:

# %%
# %load_ext autoreload
# %autoreload 2

from skimage import io
import matplotlib.pyplot as plt
from IPython.display import SVG, display

from scraper.canyon_scraper import canyon_geometry_scraper

# %% [markdown]
# ## Canyon bikes' geometry web scraping:

# %% [markdown]
# ### Generate dataframe:

# %%
# site_url1 = 'https://www.canyon.com/en-hu/road-bikes/race-bikes/aeroad/aeroad-cfr-disc-eps/2493.html'
site_url1 = 'https://www.canyon.com/en-hu/mountain-bikes/trail-bikes/spectral/spectral-29-ltd/2682.html'

scraper = canyon_geometry_scraper(site_url = site_url1)
df = scraper.generate_df()
df
# Out:
#                                                  S          M          L  \
# Body Height in cm                            < 175  175 - 183  183 - 192
# Seat Height in mm (a)                    626 - 758  691 - 823  721 - 853
# Seat Tube Length in mm (b)                     395        430        460
# Top Tube Length in mm (c)                      582        609        636
# Head Tube Length in mm (d)                      95        105        115
# Head Tube Angle (e)                          64,5°      64,5°      64,5°
# Seat Tube Angle (f)                          76,5°      76,5°      76,5°
# Chainstay Length in mm (g)                     437        437        437
# Wheel Base in mm (h)                         1.193      1.222      1.251
# Stack in mm (i)                                611        620        629
# Reach in mm (j)                                435        460        485
# Stand-over Height in mm (k)                    755        762        767
# Bottom Bracket Offset in mm (l)                 36         36         36
# Spacer in mm                                  20,0       20,0       20,0
# Stem Length in mm                               40         40         40
# Handlebar Width in mm                          760        780        780
# Crank Length in mm                           170,0      170,0      170,0
# Chainring Size                                  32         32         32
# Seat Post Diameter in mm                      30,9       30,9       30,9
# Seat Post Length in mm                         405        465        465
# Maximum Seat Post Insertion Depth in mm        222        252        252
# Seat Post Insertion Depth in mm                 90        120        120
# Wheel Size                                     29"        29"        29"
# Disc Size in mm                          180 / 203  180 / 203  180 / 203
# Front Fork Travel in mm                        160        160        160
# Rear Suspension Travel in mm                   150        150        150
#
#                                                 XL
# Body Height in cm                            > 192
# Seat Height in mm (a)                    751 - 883
# Seat Tube Length in mm (b)                     490
# Top Tube Length in mm (c)                      663
# Head Tube Length in mm (d)                     125
# Head Tube Angle (e)                          64,5°
# Seat Tube Angle (f)                          76,5°
# Chainstay Length in mm (g)                     437
# Wheel Base in mm (h)                         1.281
# Stack in mm (i)                                638
# Reach in mm (j)                                510
# Stand-over Height in mm (k)                    775
# Bottom Bracket Offset in mm (l)                 36
# Spacer in mm                                  20,0
# Stem Length in mm                               40
# Handlebar Width in mm                          780
# Crank Length in mm                           170,0
# Chainring Size                                  32
# Seat Post Diameter in mm                      30,9
# Seat Post Length in mm                         465
# Maximum Seat Post Insertion Depth in mm        252
# Seat Post Insertion Depth in mm                120
# Wheel Size                                     29"
# Disc Size in mm                          180 / 203
# Front Fork Travel in mm                        160
# Rear Suspension Travel in mm                   150

# %% [markdown]
# ### Frame geometry image:

# %%
display(SVG(url=scraper.get_frame_geom_img_url()))

# %% [markdown]
# ## Trek bikes' geometry web scraping:
